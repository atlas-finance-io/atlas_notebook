# %%
import ccxt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from ta.trend import IchimokuIndicator
from ta.trend import ADXIndicator
from ta.trend import PSARIndicator

from ta.momentum import RSIIndicator
from ta.momentum import StochasticOscillator


from IPython.display import display
from tabulate import tabulate
from datetime import datetime

# Set the style of matplotlib to 'dark_background'
plt.style.use('dark_background')

# Configure pandas to display all rows and columns without line breaks
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 0)  # Set display width to 0 to prevent wrapping
pd.set_option('display.max_colwidth', None)  # Deprecated, use None instead

# %%
universe = [
    'BTCUSDT', 'ETHUSDT', 'BNBUSDT', 'NEOUSDT', 'LTCUSDT', 'QTUMUSDT', 'ADAUSDT', 'XRPUSDT', 'EOSUSDT', 'IOTAUSDT',
    'XLMUSDT', 'ONTUSDT', 'TRXUSDT', 'ETCUSDT', 'ICXUSDT', 'VETUSDT', 'LINKUSDT', 'WAVESUSDT', 'HOTUSDT',
    'ZILUSDT', 'ZRXUSDT', 'FETUSDT', 'BATUSDT', 'XMRUSDT', 'ZECUSDT', 'IOSTUSDT', 'CELRUSDT', 'DASHUSDT', 'OMGUSDT',
    'THETAUSDT', 'ENJUSDT', 'MATICUSDT', 'ATOMUSDT', 'ONEUSDT', 'FTMUSDT', 'ALGOUSDT', 'DOGEUSDT', 'DUSKUSDT', 'ANKRUSDT',
    'COMBOUSDT', 'MTLUSDT', 'TOMOUSDT', 'DENTUSDT', 'KEYUSDT', 'CVCUSDT', 'CHZUSDT', 'BANDUSDT', 'XTZUSDT', 'RENUSDT',
    'RVNUSDT', 'HBARUSDT', 'NKNUSDT', 'STXUSDT', 'KAVAUSDT', 'ARPAUSDT', 'IOTXUSDT', 'RLCUSDT', 'BCHUSDT', 'FTTUSDT',
    'OGNUSDT', 'BTSUSDT', 'BNTUSDT', 'COTIUSDT', 'SOLUSDT', 'CTSIUSDT', 'CHRUSDT', 'MDTUSDT', 'STMXUSDT', 'KNCUSDT',
    'LRCUSDT', 'COMPUSDT', 'SCUSDT', 'ZENUSDT', 'SNXUSDT', 'DGBUSDT', 'SXPUSDT', 'MKRUSDT', 'STORJUSDT', 'MANAUSDT',
    'YFIUSDT', 'BALUSDT', 'BLZUSDT', 'SRMUSDT', 'ANTUSDT', 'CRVUSDT', 'SANDUSDT', 'OCEANUSDT', 'NMRUSDT', 'DOTUSDT',
    'RSRUSDT', 'TRBUSDT', 'SUSHIUSDT', 'KSMUSDT', 'EGLDUSDT', 'RUNEUSDT', 'UMAUSDT', 'BELUSDT', 'UNIUSDT', 'OXTUSDT',
    'AVAXUSDT', 'HNTUSDT', 'FLMUSDT', 'XVSUSDT', 'ALPHAUSDT', 'AAVEUSDT', 'NEARUSDT', 'FILUSDT', 'INJUSDT', 'AUDIOUSDT',
    'CTKUSDT', 'AXSUSDT', 'UNFIUSDT', 'ROSEUSDT', 'XEMUSDT', 'SKLUSDT', 'GRTUSDT', '1INCHUSDT', 'REEFUSDT', 'CELOUSDT',
    'TRUUSDT', 'CKBUSDT', 'LITUSDT', 'SFPUSDT', 'ALICEUSDT', 'LINAUSDT', 'PERPUSDT', 'CFXUSDT', 'TLMUSDT', 'BAKEUSDT',
    'ICPUSDT', 'ARUSDT', 'MASKUSDT', 'LPTUSDT', 'XVGUSDT', 'ATAUSDT', 'GTCUSDT', 'KLAYUSDT', 'C98USDT', 'QNTUSDT',
    'FLOWUSDT', 'MINAUSDT', 'RAYUSDT', 'DYDXUSDT', 'IDEXUSDT', 'GALAUSDT', 'YGGUSDT', 'AGLDUSDT', 'RADUSDT', 'DARUSDT',
    'BNXUSDT', 'ENSUSDT', 'JASMYUSDT', 'RNDRUSDT', 'FXSUSDT', 'HIGHUSDT', 'CVXUSDT', 'PEOPLEUSDT', 'SPELLUSDT', 'JOEUSDT',
    'ACHUSDT', 'IMXUSDT', 'API3USDT', 'WOOUSDT', 'TUSDT', 'ASTRUSDT', 'GMTUSDT', 'APEUSDT', 'GALUSDT', 'LDOUSDT',
    'OPUSDT', 'LEVERUSDT', 'STGUSDT', 'GMXUSDT', 'APTUSDT', 'HFTUSDT'
]

# %%
exchange = ccxt.binance({
    'enableRateLimit': True,
})

# Function to fetch OHLCV data
def fetch_ohlcv_data(symbol, timeframe):
    since = 0  # Set to 0 to fetch the full history
    all_ohlcv_data = []
    while True:
        ohlcv_data = exchange.fetch_ohlcv(symbol, timeframe, since)
        if not ohlcv_data:
            break
        since = ohlcv_data[-1][0] + 1  # Update since to the timestamp of the last candle
        all_ohlcv_data.extend(ohlcv_data)
    for i in range(len(all_ohlcv_data)):
        all_ohlcv_data[i][0] = datetime.utcfromtimestamp(all_ohlcv_data[i][0] / 1000)
    return all_ohlcv_data

ohlcv_daily = {}
start_dates = {}  # Dictionary to store the start dates for each symbol

# Fetch and store the full history of daily OHLCV data for each symbol
for symbol in universe:
    daily_data = fetch_ohlcv_data(symbol, '1h')
    ohlcv_daily[symbol] = pd.DataFrame(daily_data, columns=['date', 'open', 'high', 'low', 'close', 'volume'])
    
    # Calculate Stochastic Oscillator
    stochastic_oscillator = StochasticOscillator(high=ohlcv_daily[symbol]['high'], low=ohlcv_daily[symbol]['low'], close=ohlcv_daily[symbol]['close'], window=14, smooth_window=3)
    ohlcv_daily[symbol]['stoch_k'] = stochastic_oscillator.stoch()
    
    # RSI
    rsi_indicator = RSIIndicator(close=ohlcv_daily[symbol]['close'], window=14)
    ohlcv_daily[symbol]['rsi'] = rsi_indicator.rsi()
    
    # Store the start date for the symbol
    start_dates[symbol] = ohlcv_daily[symbol]['date'].iloc[0]

# Create a DataFrame from the start_dates dictionary
start_dates_df = pd.DataFrame(list(start_dates.items()), columns=['symbol', 'start_date'])

start_dates_df
# Out:
#          symbol          start_date
# 0       BTCUSDT 2017-08-17 04:00:00
# 1       ETHUSDT 2017-08-17 04:00:00
# 2       BNBUSDT 2017-11-06 03:00:00
# 3       NEOUSDT 2017-11-20 03:00:00
# 4       LTCUSDT 2017-12-13 03:00:00
# 5      QTUMUSDT 2018-03-19 08:00:00
# 6       ADAUSDT 2018-04-17 04:00:00
# 7       XRPUSDT 2018-05-04 08:00:00
# 8       EOSUSDT 2018-05-28 05:00:00
# 9      IOTAUSDT 2018-05-31 09:00:00
# 10      XLMUSDT 2018-05-31 09:00:00
# 11      ONTUSDT 2018-06-08 07:00:00
# 137     C98USDT 2021-07-23 12:00:00
# 138     QNTUSDT 2021-07-29 06:00:00
# 139    FLOWUSDT 2021-07-30 13:00:00
# 140    MINAUSDT 2021-08-10 06:00:00
# 141     RAYUSDT 2021-08-10 06:00:00
# 142    DYDXUSDT 2021-09-09 02:00:00
# 143    IDEXUSDT 2021-09-09 08:00:00
# 144    GALAUSDT 2021-09-13 06:00:00
# 145     YGGUSDT 2021-09-24 06:00:00
# 146    AGLDUSDT 2021-10-05 07:00:00
# 147     RADUSDT 2021-10-07 07:00:00
# 148     DARUSDT 2021-11-04 08:00:00
# 149     BNXUSDT 2021-11-04 11:00:00
# 150     ENSUSDT 2021-11-10 07:00:00
# 151   JASMYUSDT 2021-11-22 12:00:00
# 152    RNDRUSDT 2021-11-27 10:00:00
# 153     FXSUSDT 2021-12-10 09:00:00
# 154    HIGHUSDT 2021-12-17 07:00:00
# 155     CVXUSDT 2021-12-23 14:00:00
# 156  PEOPLEUSDT 2021-12-23 06:00:00
# 157   SPELLUSDT 2021-12-24 08:00:00
# 158     JOEUSDT 2021-12-28 11:00:00
# 159     ACHUSDT 2022-01-10 10:00:00
# 160     IMXUSDT 2022-01-10 10:00:00
# 161    API3USDT 2022-01-21 10:00:00
# 162     WOOUSDT 2022-02-08 06:00:00
# 163       TUSDT 2022-02-25 04:00:00
# 164    ASTRUSDT 2022-02-28 11:00:00
# 165     GMTUSDT 2022-03-09 12:00:00
# 166     APEUSDT 2022-03-17 14:00:00
# 167     GALUSDT 2022-05-05 12:00:00
# 168     LDOUSDT 2022-05-09 11:00:00
# 169      OPUSDT 2022-06-01 08:00:00
# 170   LEVERUSDT 2022-07-13 04:00:00
# 171     STGUSDT 2022-08-19 09:00:00
# 172     GMXUSDT 2022-10-05 10:00:00
# 173     APTUSDT 2022-10-19 01:00:00
# 174     HFTUSDT 2022-11-07 13:00:00

# %%
def fetch_full_ohlcv_history(symbol, timeframe='1d'):
    all_ohlcv = []
    since = 0  # Set to 0 to fetch from the earliest available data
    while True:
        ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since, 1000)
        if not ohlcv:
            break
        all_ohlcv.extend(ohlcv)
        since = ohlcv[-1][0] + 1  # Increment 'since' to get the next batch of data
    df = pd.DataFrame(all_ohlcv, columns=['date', 'open', 'high', 'low', 'close', 'volume'])  # Renamed 'timestamp' to 'date'
    df['date'] = pd.to_datetime(df['date'], unit='ms')
    df.set_index('date', inplace=True)
    return df

# Fetch the full history of daily prices for Bitcoin
btc_ohlcv = fetch_full_ohlcv_history('BTCUSDT')

# Calculate daily returns for Bitcoin
btc_ohlcv['returns'] = btc_ohlcv['close'].pct_change()

# %%
def is_btc_return_positive(date):
    return btc_ohlcv.loc[date, 'returns'] > 0

stoch_rsi_stats = {}

# Loop through each symbol in the ohlcv_daily dictionary
for symbol in ohlcv_daily:
    
    # Initialize counters for successful combined predictions
    successful_combined_predictions = 0
    combined_signal_count = 0
    percentage_increases = []
    
    # Loop through the data to find %K below 20 and RSI below 30
    for i in range(1, len(ohlcv_daily[symbol]) - 5):  # Exclude the last 10 days for forward checking
        
        # Check for %K below 20 and RSI below 30
        if ohlcv_daily[symbol]['stoch_k'][i] < 20 and ohlcv_daily[symbol]['rsi'][i] < 30:

            current_date = ohlcv_daily[symbol]['date'][i].strftime("%Y-%m-%d")
            btc_return_positive = is_btc_return_positive(current_date)

            if btc_return_positive: 
                combined_signal_count += 1
                
                # Check if the price increased after 5 periods
                if ohlcv_daily[symbol]['close'][i + 5] > ohlcv_daily[symbol]['close'][i]:
                    increase = (ohlcv_daily[symbol]['close'][i + 5] / ohlcv_daily[symbol]['close'][i]) / 100
                    percentage_increases.append(increase)
                    successful_combined_predictions += 1
    
    # Calculate the effectiveness percentage
    if combined_signal_count > 0:
        combined_effectiveness_percentage = (successful_combined_predictions / combined_signal_count) * 100
    else:
        combined_effectiveness_percentage = None

    mean_percent = np.mean(percentage_increases) 
    
    # Store the combined stats in the dictionary
    stoch_rsi_stats[symbol] = {'signal_count': combined_signal_count, 'effectiveness': combined_effectiveness_percentage, 'average_increase': mean_percent}

# Sort the dictionary by effectiveness in decreasing order
sorted_stoch_rsi_stats = sorted(stoch_rsi_stats.items(), key=lambda item: item[1]['effectiveness'] if item[1]['effectiveness'] is not None else -1, reverse=True)

# Display the sorted results
for symbol, stats in sorted_stoch_rsi_stats:
    if stats['effectiveness'] is not None:
        print(f"{symbol}: Combined Stochastic & RSI Effectiveness: {stats['effectiveness']:.2f}%, Signal Count: {stats['signal_count']} with average increase of {stats['average_increase']}")
    else:
        print(f"{symbol}: No combined Stochastic & RSI signals, Signal Count: {stats['signal_count']}")
# Out:
# BTCUSDT: Combined Stochastic & RSI Effectiveness: 86.02%, Signal Count: 236 with average increase of 0.010240529593615077
# ALICEUSDT: Combined Stochastic & RSI Effectiveness: 84.78%, Signal Count: 184 with average increase of 0.010289142514348901
# MANAUSDT: Combined Stochastic & RSI Effectiveness: 82.91%, Signal Count: 199 with average increase of 0.010295466174837408
# XTZUSDT: Combined Stochastic & RSI Effectiveness: 81.57%, Signal Count: 217 with average increase of 0.010273971209137941
# DGBUSDT: Combined Stochastic & RSI Effectiveness: 80.41%, Signal Count: 194 with average increase of 0.010291020297012916
# STXUSDT: Combined Stochastic & RSI Effectiveness: 80.32%, Signal Count: 310 with average increase of 0.01030972885579936
# EGLDUSDT: Combined Stochastic & RSI Effectiveness: 80.28%, Signal Count: 213 with average increase of 0.010245910551669579
# ETCUSDT: Combined Stochastic & RSI Effectiveness: 80.18%, Signal Count: 227 with average increase of 0.010258641384432811
# LTCUSDT: Combined Stochastic & RSI Effectiveness: 79.84%, Signal Count: 253 with average increase of 0.010260760370968312
# RVNUSDT: Combined Stochastic & RSI Effectiveness: 79.78%, Signal Count: 183 with average increase of 0.010303452753691076
# DOTUSDT: Combined Stochastic & RSI Effectiveness: 79.39%, Signal Count: 165 with average increase of 0.010290066907232113
# DOGEUSDT: Combined Stochastic & RSI Effectiveness: 79.14%, Signal Count: 139 with average increase of 0.010250742614956423
# ATAUSDT: Combined Stochastic & RSI Effectiveness: 78.89%, Signal Count: 180 with average increase of 0.010299642939001544
# SOLUSDT: Combined Stochastic & RSI Effectiveness: 78.87%, Signal Count: 194 with average increase of 0.010342252156036647
# TRBUSDT: Combined Stochastic & RSI Effectiveness: 69.59%, Signal Count: 296 with average increase of 0.010298808837874074
# OXTUSDT: Combined Stochastic & RSI Effectiveness: 69.44%, Signal Count: 216 with average increase of 0.01025660542495831
# C98USDT: Combined Stochastic & RSI Effectiveness: 69.36%, Signal Count: 173 with average increase of 0.010235233171136053
# APEUSDT: Combined Stochastic & RSI Effectiveness: 69.31%, Signal Count: 101 with average increase of 0.01029391237001959
# ARUSDT: Combined Stochastic & RSI Effectiveness: 69.08%, Signal Count: 152 with average increase of 0.010324943097044284
# ALPHAUSDT: Combined Stochastic & RSI Effectiveness: 69.07%, Signal Count: 236 with average increase of 0.010321975377464414
# SNXUSDT: Combined Stochastic & RSI Effectiveness: 69.06%, Signal Count: 265 with average increase of 0.010305119467986748
# NMRUSDT: Combined Stochastic & RSI Effectiveness: 68.81%, Signal Count: 218 with average increase of 0.010281206106155277
# FLOWUSDT: Combined Stochastic & RSI Effectiveness: 68.78%, Signal Count: 205 with average increase of 0.010245242064559732
# COMBOUSDT: Combined Stochastic & RSI Effectiveness: 68.63%, Signal Count: 51 with average increase of 0.010265921239976853
# ANKRUSDT: Combined Stochastic & RSI Effectiveness: 68.62%, Signal Count: 290 with average increase of 0.010300015363534653
# FETUSDT: Combined Stochastic & RSI Effectiveness: 68.55%, Signal Count: 372 with average increase of 0.010310687986484513
# ZECUSDT: Combined Stochastic & RSI Effectiveness: 68.53%, Signal Count: 286 with average increase of 0.010238961639858976
# RAYUSDT: Combined Stochastic & RSI Effectiveness: 68.48%, Signal Count: 257 with average increase of 0.010233910559896033
# SKLUSDT: Combined Stochastic & RSI Effectiveness: 68.35%, Signal Count: 237 with average increase of 0.010292277051219382
# SCUSDT: Combined Stochastic & RSI Effectiveness: 68.30%, Signal Count: 306 with average increase of 0.010273572114343875
# KSMUSDT: Combined Stochastic & RSI Effectiveness: 68.29%, Signal Count: 246 with average increase of 0.010264639753187607
# BALUSDT: Combined Stochastic & RSI Effectiveness: 68.13%, Signal Count: 251 with average increase of 0.01023800673096834
# CELRUSDT: Combined Stochastic & RSI Effectiveness: 67.66%, Signal Count: 402 with average increase of 0.01027419447749299
# BELUSDT: Combined Stochastic & RSI Effectiveness: 67.66%, Signal Count: 303 with average increase of 0.01027407021403127
# SRMUSDT: Combined Stochastic & RSI Effectiveness: 67.58%, Signal Count: 256 with average increase of 0.010343545185038902
# PEOPLEUSDT: Combined Stochastic & RSI Effectiveness: 67.54%, Signal Count: 114 with average increase of 0.01026550914037373
# RLCUSDT: Combined Stochastic & RSI Effectiveness: 67.20%, Signal Count: 311 with average increase of 0.010337931624011332
# RADUSDT: Combined Stochastic & RSI Effectiveness: 67.16%, Signal Count: 201 with average increase of 0.010200527942954623
# RNDRUSDT: Combined Stochastic & RSI Effectiveness: 67.11%, Signal Count: 149 with average increase of 0.010313107082712006
# SUSHIUSDT: Combined Stochastic & RSI Effectiveness: 67.06%, Signal Count: 252 with average increase of 0.010463238400474405
# XMRUSDT: Combined Stochastic & RSI Effectiveness: 67.05%, Signal Count: 264 with average increase of 0.010263847734150015
# SXPUSDT: Combined Stochastic & RSI Effectiveness: 67.02%, Signal Count: 282 with average increase of 0.01030336297510733
# MTLUSDT: Combined Stochastic & RSI Effectiveness: 66.88%, Signal Count: 308 with average increase of 0.010247739011985243
# PERPUSDT: Combined Stochastic & RSI Effectiveness: 66.67%, Signal Count: 285 with average increase of 0.010298989619555596
# CFXUSDT: Combined Stochastic & RSI Effectiveness: 66.34%, Signal Count: 202 with average increase of 0.01023108932746198
# HNTUSDT: Combined Stochastic & RSI Effectiveness: 66.33%, Signal Count: 196 with average increase of 0.010330755208066224
# ENSUSDT: Combined Stochastic & RSI Effectiveness: 65.96%, Signal Count: 141 with average increase of 0.01029516787893873
# GTCUSDT: Combined Stochastic & RSI Effectiveness: 65.80%, Signal Count: 231 with average increase of 0.010291146408881098
# BTSUSDT: Combined Stochastic & RSI Effectiveness: 65.74%, Signal Count: 251 with average increase of 0.010254935483024948
# CRVUSDT: Combined Stochastic & RSI Effectiveness: 65.14%, Signal Count: 284 with average increase of 0.0104772128567813
# ANTUSDT: Combined Stochastic & RSI Effectiveness: 65.04%, Signal Count: 246 with average increase of 0.010217409339612928
# AAVEUSDT: Combined Stochastic & RSI Effectiveness: 64.41%, Signal Count: 222 with average increase of 0.010297198557999954
# LPTUSDT: Combined Stochastic & RSI Effectiveness: 64.40%, Signal Count: 250 with average increase of 0.010221298747034724
# HIGHUSDT: Combined Stochastic & RSI Effectiveness: 63.86%, Signal Count: 202 with average increase of 0.01024339271425885
# LINAUSDT: Combined Stochastic & RSI Effectiveness: 63.76%, Signal Count: 287 with average increase of 0.010240905311814385
# FILUSDT: Combined Stochastic & RSI Effectiveness: 63.43%, Signal Count: 216 with average increase of 0.0102180606329151
# XVGUSDT: Combined Stochastic & RSI Effectiveness: 63.19%, Signal Count: 182 with average increase of 0.010279940040141747
# DUSKUSDT: Combined Stochastic & RSI Effectiveness: 63.03%, Signal Count: 357 with average increase of 0.010319519451490093
# OPUSDT: Combined Stochastic & RSI Effectiveness: 62.50%, Signal Count: 88 with average increase of 0.010196891806816098
# KLAYUSDT: Combined Stochastic & RSI Effectiveness: 62.23%, Signal Count: 233 with average increase of 0.010195420128325618
# TOMOUSDT: Combined Stochastic & RSI Effectiveness: 62.23%, Signal Count: 368 with average increase of 0.010374681566407034
# KNCUSDT: Combined Stochastic & RSI Effectiveness: 62.19%, Signal Count: 320 with average increase of 0.010224530854288769
# CVXUSDT: Combined Stochastic & RSI Effectiveness: 61.17%, Signal Count: 206 with average increase of 0.010229558870705525
# STGUSDT: Combined Stochastic & RSI Effectiveness: 58.06%, Signal Count: 186 with average increase of 0.010149077272109112
# LEVERUSDT: Combined Stochastic & RSI Effectiveness: 57.38%, Signal Count: 122 with average increase of 0.010299750856574889
# GMXUSDT: Combined Stochastic & RSI Effectiveness: 52.87%, Signal Count: 157 with average increase of 0.010153328457460841
# FXSUSDT: Combined Stochastic & RSI Effectiveness: 51.49%, Signal Count: 369 with average increase of 0.010213299041685348
# BNXUSDT: Combined Stochastic & RSI Effectiveness: 49.84%, Signal Count: 305 with average increase of 0.010229092378028163
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
